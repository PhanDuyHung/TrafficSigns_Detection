# %%
# Load pickled data
import pickle
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np


training_file = "C:/Users/LAPTOP64/Desktop/trafiic-signs-data/train.p"
#validation_file="C:/Users/LAPTOP64/Desktop/trafiic-signs-data//valid.p"
testing_file = "C:/Users/LAPTOP64/Desktop/trafiic-signs-data/test.p"

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
#with open(validation_file, mode='rb') as f:
#   valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)

#current: X_train: 39208    y_train: 39208 - 42    
#current: x_test: 12629    y_test: 12629 - 10
X_train, y_train = train['features'], train['labels']
#X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
# %matplotlib inline
plt.imshow(X_train[45000])
y_train[45000]
# Out:
# 50

# %%
import cv2
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline
                    
image = mpimg.imread('C:\\Users\\LAPTOP64\\Desktop\\trafiic-signs-data\\images_data\\Maximum-40km\\0001.jpg',1)
plt.imshow(image)

(height, width) = image.shape[:2]
print(height)
print(width)

(x,y,z) = image[16][16]
print(x)
print(y)
print(z)
# Out:
# 189
# 266
# 74
# 81
# 37

# %%
X_train = np.append(X_train, [image], axis = 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-fccd2595c4e5> in <module>()
#       1
# ----> 2 X_train = np.append(X_train, [image], axis = 0)
#
# E:\Tools\Anaconda\Anaconda\envs\tfdeeplearning\lib\site-packages\numpy\lib\function_base.py in append(arr, values, axis)
#    5145         values = ravel(values)
#    5146         axis = arr.ndim-1
# -> 5147     return concatenate((arr, values), axis=axis)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly

# %%
X_train[39209][31]
# Out:
# array([[ 37,  30,  22],
#        [140, 134, 118],
#        [175, 168, 152],
#        [177, 171, 149],
#        [180, 174, 150],
#        [180, 174, 148],
#        [180, 175, 146],
#        [185, 177, 158],
#        [184, 179, 157],
#        [169, 172, 143],
#        [174, 173, 145],
#        [180, 175, 153],
#        [174, 177, 156],
#        [181, 179, 158],
#        [183, 176, 157],
#        [192, 185, 167],
#        [186, 186, 162],
#        [171, 169, 146],
#        [183, 183, 159],
#        [172, 175, 154],
#        [180, 183, 162],
#        [178, 174, 149],
#        [178, 176, 155],
#        [182, 180, 159],
#        [185, 179, 153],
#        [182, 182, 156],
#        [179, 179, 155],
#        [177, 176, 155],
#        [173, 172, 151],
#        [164, 159, 137],
#        [175, 170, 148],
#        [ 29,  24,   5]], dtype=uint8)

# %%
type(image)

# %%
image.shape

# %%
X_train.shape
# Out:
# (39210, 32, 32, 3)

# %%
plt.imshow(X_train[39209])

# %%
X_train[39309]
y_train[39309]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-2311398f6b4b> in <module>()
# ----> 1 X_train[39309]
#       2 y_train[39309]
#
# IndexError: index 39309 is out of bounds for axis 0 with size 39309

# %%
for i in range(39209, 39309):
    y_train = np.append(y_train,43)

# %%
plt.imshow(X_train[392])

# %%
##ADD train
import os
import numpy as np

img_folder = 'C:\\Users\\LAPTOP64\\Desktop\\trafiic-signs-data\\images_data\\dataset\\out\\'

for img_name in os.listdir(img_folder):
    image = mpimg.imread(img_folder+img_name)
    X_train = np.append(X_train, [image], axis = 0)
    y_train = np.append(y_train,49)

# %%
# %matplotlib inline
plt.imshow(X_train[45362])
y_train[45362]
# Out:
# 14

# %%
train['features'] = X_train
train['labels'] = y_train

with open(training_file, mode='wb') as f:
    pickle.dump(train, f)

# %%
X_test[1263]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-123-5e4fa360e887> in <module>()
# ----> 1 X_test[12630]
#
# IndexError: index 12630 is out of bounds for axis 0 with size 12630

# %%
##ADD test
import os
import numpy as np

img_folder = 'C:\\Users\\LAPTOP64\\Desktop\\trafiic-signs-data\\images_data\\dataset\\out\\'

for img_name in os.listdir(img_folder):
    image = mpimg.imread(img_folder+img_name)
    X_test = np.append(X_test, [image], axis = 0)
    y_test = np.append(y_test,49)

# %%
test['features'] = X_test
test['labels'] = y_test

with open(testing_file, mode='wb') as f:
    pickle.dump(test, f)

# %%
y_test[13234]
# Out:
# 49
