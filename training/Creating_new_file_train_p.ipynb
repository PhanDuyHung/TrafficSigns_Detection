# %%
train = {'features':None,'labels':None}
image = mpimg.imread('C:\\Users\\LAPTOP64\\Desktop\\vodka\\real\\0000.jpg')


X_train = [image]
y_train = 1

train['features'],train['labels'] = X_train, y_train

# image = mpimg.imread('C:\\Users\\LAPTOP64\\Desktop\\vodka\\real\\0001.jpg')
# X_train = np.append(X_train, [image], axis = 0)
# y_train = np.append(y_train,1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(train['features'][0])
train['labels']
# Out:
# 1

# %%
train['features'] = X_train
train['labels'] = y_train

training_file = "C:/Users/LAPTOP64/Desktop/vodka/train.p"
testing_file = "C:/Users/LAPTOP64/Desktop/vodka/test.p"
with open(training_file, mode='wb') as f:
    pickle.dump(train, f)

# %%
# Load pickled data
import pickle
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np

import os

training_file = "C:/Users/LAPTOP64/Desktop/vodka/train.p"
testing_file = "C:/Users/LAPTOP64/Desktop/vodka/test.p"

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
#with open(validation_file, mode='rb') as f:
#   valid = pickle.load(f)
# with open(testing_file, mode='rb') as f:
#     test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
#X_test, y_test = test['features'], test['labels']

# %%
plt.imshow(X_train[0])
y_train[0]
# Out:
# 1

# %%
img_folder = 'C:\\Users\\LAPTOP64\\Desktop\\vodka\\real\\'

for img_name in os.listdir(img_folder):
    image = mpimg.imread(img_folder+img_name)
    X_train = np.append(X_train, [image], axis = 0)
    y_train = np.append(y_train,1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-e29dc1f99118> in <module>()
#       3 for img_name in os.listdir(img_folder):
#       4     image = mpimg.imread(img_folder+img_name)
# ----> 5     X_train = np.append(X_train, [image], axis = 0)
#       6     y_train = np.append(y_train,1)
#
# E:\Tools\Anaconda\Anaconda\envs\tfdeeplearning\lib\site-packages\numpy\lib\function_base.py in append(arr, values, axis)
#    5145         values = ravel(values)
#    5146         axis = arr.ndim-1
# -> 5147     return concatenate((arr, values), axis=axis)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly
